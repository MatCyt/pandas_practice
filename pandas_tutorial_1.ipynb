# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('zoo.csv', delimiter = ',')
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
url = 'http://46.101.230.157/dilan/pandas_tutorial_read.csv'
column_names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic']
article_read = pd.read_csv(url, delimiter = ';', names = column_names)

article_read
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
article_read.head(2)
# Out:
#            my_datetime event    country     user_id source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America

# %%
article_read.tail(2)
# Out:
#               my_datetime event    country     user_id   source   topic
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords  Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit    Asia

# %%
article_read.sample(5)
# Out:
#               my_datetime event    country     user_id   source          topic
# 1709  2018-01-01 23:03:14  read  country_2  2458152970   Reddit         Africa
# 899   2018-01-01 12:07:02  read  country_7  2458152160      SEO  North America
# 142   2018-01-01 02:06:11  read  country_5  2458151403   Reddit           Asia
# 756   2018-01-01 10:09:20  read  country_7  2458152017   Reddit  South America
# 1351  2018-01-01 18:19:39  read  country_7  2458152612  AdWords           Asia

# %%
article_read[['country', 'source', 'event']]
# Out:
#         country   source event
# 0     country_7      SEO  read
# 1     country_7      SEO  read
# 2     country_7  AdWords  read
# 3     country_7  AdWords  read
# 4     country_8   Reddit  read
# 5     country_6   Reddit  read
# 6     country_2   Reddit  read
# 7     country_6  AdWords  read
# 8     country_7  AdWords  read
# 9     country_5   Reddit  read
# 10    country_5  AdWords  read
# 11    country_7      SEO  read
# 12    country_5   Reddit  read
# 13    country_2   Reddit  read
# 14    country_7   Reddit  read
# 15    country_7      SEO  read
# 16    country_8      SEO  read
# 17    country_2   Reddit  read
# 18    country_4      SEO  read
# 19    country_2   Reddit  read
# 20    country_2   Reddit  read
# 21    country_7   Reddit  read
# 22    country_2  AdWords  read
# 23    country_2   Reddit  read
# 24    country_7   Reddit  read
# 25    country_2  AdWords  read
# 26    country_5      SEO  read
# 27    country_2      SEO  read
# 28    country_2   Reddit  read
# ...

# %%
article_read.country # print series instead of df
# Out:
# 0       country_7
# 1       country_7
# 2       country_7
# 3       country_7
# 4       country_8
# 5       country_6
# 6       country_2
# 7       country_6
# 8       country_7
# 9       country_5
# 10      country_5
# 11      country_7
# 12      country_5
# 13      country_2
# 14      country_7
# 15      country_7
# 16      country_8
# 17      country_2
# 18      country_4
# 19      country_2
# 20      country_2
# 21      country_7
# 22      country_2
# 23      country_2
# 24      country_7
# 25      country_2
# 26      country_5
# 27      country_2
# 28      country_2
# 29      country_7
#           ...
# 1765    country_2
# 1766    country_5
# 1767    country_5
# 1768    country_8
# 1769    country_5
# 1770    country_6
# 1771    country_5
# 1772    country_7
# 1773    country_8
# 1774    country_2
# 1775    country_2
# 1776    country_6
# 1777    country_5
# 1778    country_2
# 1779    country_4
# 1780    country_8
# 1781    country_2
# 1782    country_2
# 1783    country_3
# ...

# %%
# filter for a value
article_read[article_read.source == 'SEO']
article_read[article_read['source'] == 'SEO']
# Out:
#               my_datetime event    country     user_id source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11    2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15    2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# 18    2018-01-01 00:13:39  read  country_4  2458151279    SEO  North America
# 26    2018-01-01 00:20:18  read  country_5  2458151287    SEO  North America
# 27    2018-01-01 00:20:44  read  country_2  2458151288    SEO  North America
# 30    2018-01-01 00:24:52  read  country_6  2458151291    SEO  North America
# 41    2018-01-01 00:35:23  read  country_5  2458151302    SEO           Asia
# 54    2018-01-01 00:46:42  read  country_5  2458151315    SEO  North America
# ...

# %%
article_read[article_read.country == 'country_2'][['user_id', 'topic', 'country']]
# Out:
#          user_id          topic    country
# 6     2458151267         Europe  country_2
# 13    2458151274         Europe  country_2
# 17    2458151278           Asia  country_2
# 19    2458151280           Asia  country_2
# 20    2458151281           Asia  country_2
# 22    2458151283         Europe  country_2
# 23    2458151284           Asia  country_2
# 25    2458151286  North America  country_2
# 27    2458151288  North America  country_2
# 28    2458151289           Asia  country_2
# 34    2458151295  North America  country_2
# 44    2458151305           Asia  country_2
# 48    2458151309           Asia  country_2
# 53    2458151314           Asia  country_2
# 57    2458151318         Europe  country_2
# 70    2458151331  South America  country_2
# 71    2458151332           Asia  country_2
# 73    2458151334  North America  country_2
# 82    2458151343         Africa  country_2
# 83    2458151344  South America  country_2
# 97    2458151358  North America  country_2
# ...
